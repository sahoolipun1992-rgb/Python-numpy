# %% [markdown]
# # Session 1: Python Fundamentals

# %% [markdown]
# ## 1. Python Output

# %%
# Simple print statement
print('Hello World')

# %%
# Python is case sensitive
# Print('Hello World') # This will throw an error

# %%
# Printing numbers and booleans
print(7)
print(7.7)
print(True)

# %%
# Printing multiple values
print('Hello', 1, 4.5, True)

# %%
# Using 'sep' parameter (Separator)
print('Hello', 1, 4.5, True, sep='/')

# %%
# Using 'end' parameter
print('hello', end='-')
print('world')

# %% [markdown]
# ## 2. Data Types

# %%
# Integer
print(8)
# 1*10^308
print(1e308)
print(1e309) # Python handles very large integers, but floats have limits (inf)

# %%
# Decimal/Float
print(8.55)

# %%
# Boolean
print(True)
print(False)

# %%
# Text/String
print('Hello World')

# %%
# Complex Numbers
print(5+6j)

# %%
# List (C-> Array)
print([1,2,3,4,5])

# %%
# Tuple
print((1,2,3,4,5))

# %%
# Sets
print({1,2,3,4,5})

# %%
# Dictionary
print({'name':'Nitish','gender':'Male','weight':70})

# %%
# Check data type using type()
print(type(3))
print(type(3.5))
print(type('hello'))

# %% [markdown]
# ## 3. Variables

# %%
# Static Vs Dynamic Typing
# Static Vs Dynamic Binding
# Stylish declaration techniques

name = 'nitish'
print(name)

a = 5
b = 6
print(a + b)

# %%
# Dynamic Typing (Python does not require data type declaration)
a = 5
# Dynamic Binding (Variable can store different data types in same program)
a = 'nitish'
print(a)

# %%
# Stylish declaration
a,b,c = 1,2,3
print(a,b,c)

# %%
# Multiple variables with same value
a=b=c=5
print(a,b,c)

# %% [markdown]
# ## 4. Keywords & Identifiers

# %%
# Comments
# This is a comment

# Identifiers: Names given to variables, functions, classes
# You can't start with a digit
name1 = 'Nitish'
# 1name = 'Nitish' # Error

# You can use special chars -> Only underscore (_)
first_name = 'Nitish'
print(first_name)
# first-name # Error

# Identifiers can not be keywords

# %% [markdown]
# ## 5. User Input

# %%
# Static Vs Dynamic
# Input function
input('Enter Email')

# Take input from users and store them in a variable
fnum = input('enter first number')
snum = input('enter second number')

# print(type(fnum),type(snum))

# Note: input() always returns a string, so we need type conversion for math operations

# %% [markdown]
# ## 6. Type Conversion

# %%
# Implicit Vs Explicit
# Implicit: Python automatically converts
print(5+5.6)
print(type(5),type(5.6))

# Explicit: User converts using functions
# str -> int
# int(4+5j) # Error (Complex cannot be converted to int)

# int to str
str(5)

# float
float(4)

# %%
# Correct program to add two numbers
fnum = input('enter first number')
snum = input('enter second number')

result = int(fnum) + int(snum)
print(result)

# %% [markdown]
# ## 7. Literals

# %%
a = 0b1010 # Binary Literals
b = 100 # Decimal Literal
c = 0o310 # Octal Literal
d = 0x12c # Hexadecimal Literal

# Float Literal
float_1 = 10.5
float_2 = 1.5e2 # 1.5 * 10^2
float_3 = 1.5e-3 # 1.5 * 10^-3

# Complex Literal
x = 3.14j

print(a, b, c, d)
print(float_1, float_2,float_3)
print(x, x.imag, x.real)

# %%
# String literals
string = 'This is Python'
strings = "This is Python"
char = "C"
multiline_str = """This is a multiline string with more than one line code."""
unicode = u"\U0001f600\U0001F606\U0001F923"
raw_str = r"raw \n string"

print(string)
print(strings)
print(char)
print(multiline_str)
print(unicode)
print(raw_str)

# %%
# Boolean literals
a = True + 4
b = False + 10

print("a:", a)
print("b:", b)

# %%
# None literal
a = None
print(a)
